# %% [markdown]
# #### 0.加载测试所需的函数

# %%
#!/usr/bin/env python
from test_libs import *

# %% [markdown]
# ##### 1.1卖方发布 铭文销售时 待签署的 psbt (数据来源 unisat 抓包获取)

# %%
_unsignpsbt = '...'   
commParse(_unsignpsbt)

# %% [markdown]
# ##### 1.2卖方发布 铭文销售时 待签署的 psbt (数据来源 okx 抓包获取)

# %%
_unsignedPsbt  = '...'
_unsignedPsbt = b64decode(_unsignedPsbt).hex()
commParse(_unsignedPsbt)

# %% [markdown]
# ##### 1.3卖方发布 铭文销售时 卖方已签署的 psbt (数据来源 okx 抓包获取)

# %%
_unsignedPsbt = '...'
_unsignedPsbt = b64decode(_unsignedPsbt).hex()
commParse(_unsignedPsbt)

# %% [markdown]
# ##### 2.1 买方从 okx获取的 psbt (数据来源 okx 抓包获取)

# %%
_unsignedPsbt = '...'
_unsignedPsbt = b64decode(_unsignedPsbt).hex()
commParse(_unsignedPsbt)

# %% [markdown]
# ##### 3 Input_finalizer 前后对比

# %%
print('\n==================>>>>>>>Input_finalizer 前>>>>>>>>>>>>>===================\n')
_psbt = '...'
commParse(_psbt)

# %%
print('\n==================>>>>>>>Input_finalizer 后>>>>>>>>>>>>>===================\n')
raw_psbt = unhexlify('...')    
test_finalizer = Input_Finalizer(raw_psbt)
result = test_finalizer.serialized()
# print(result.hex())   
commParse(result.hex())

# %% [markdown]
# ##### 4 tx_extractor

# %%
raw_psbt = unhexlify('...')
test_extractor = Transaction_Extractor(raw_psbt)
# test_extractor.make_file()
# print(test_extractor.__dict__)
result = test_extractor.serialized()
# print(result.hex())
TransactionParse(result.hex())
